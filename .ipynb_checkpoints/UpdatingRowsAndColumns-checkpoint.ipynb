# %%
import pandas as pd

# %%
sales = pd.read_csv("Data/sales.csv")

# %%
sales
# Out:
#            State  Total Expenses         Product  Sales   Market Size  Profit  \
# 0     California            63.0        Amaretto  109.0  Major Market  -131.0
# 1     California            55.0       Green Tea  201.0  Major Market    88.0
# 2     California           143.0     Caffe Mocha  289.0  Major Market    25.0
# 3     California           113.0  Decaf Espresso  576.0  Major Market   216.0
# 4     California            37.0       Chamomile  247.0  Major Market   148.0
# ...          ...             ...             ...    ...           ...     ...
# 4236   Wisconsin            34.0      Darjeeling   90.0  Small Market    20.0
# 4237   Wisconsin            36.0      Darjeeling  113.0  Small Market    31.0
# 4238   Wisconsin            86.0       Earl Grey  150.0  Small Market     1.0
# 4239   Wisconsin            79.0       Earl Grey  131.0  Small Market    -3.0
# 4240   Wisconsin            87.0       Earl Grey  165.0  Small Market     4.0
#
# ...

# %% [markdown]
# # get column names

# %%
sales.columns
# Out:
# Index(['State', 'Total Expenses', 'Product', 'Sales', 'Market Size', 'Profit',
#        'Market', 'Marketing', 'Product Type', 'Inventory', 'Type'],
#       dtype='object')

# %%
sales.columns.str.replace(" ","_")
# Out:
# Index(['State', 'Total_Expenses', 'Product', 'Sales', 'Market_Size', 'Profit',
#        'Market', 'Marketing', 'Product_Type', 'Inventory', 'Type'],
#       dtype='object')

# %%
sales.columns = sales.columns.str.replace(" ","_")

# %%
sales.head()
# Out:
#         State  Total_Expenses         Product  Sales   Market_Size  Profit  \
# 0  California            63.0        Amaretto  109.0  Major Market  -131.0
# 1  California            55.0       Green Tea  201.0  Major Market    88.0
# 2  California           143.0     Caffe Mocha  289.0  Major Market    25.0
# 3  California           113.0  Decaf Espresso  576.0  Major Market   216.0
# 4  California            37.0       Chamomile  247.0  Major Market   148.0
#
#   Market  Marketing Product_Type  Inventory     Type
# 0   West         40       Coffee     2947.0  Regular
# 1   West         24          Tea      659.0  Regular
# 2   West        109     Espresso      788.0  Regular
# 3   West         81     Espresso     1744.0    Decaf
# 4   West         26   Herbal Tea      809.0    Decaf

# %%
sales.Product_Type
# Out:
# 0           Coffee
# 1              Tea
# 2         Espresso
# 3         Espresso
# 4       Herbal Tea
#            ...
# 4236           Tea
# 4237           Tea
# 4238           Tea
# 4239           Tea
# 4240           Tea
# Name: Product_Type, Length: 4241, dtype: object

# %% [markdown]
# # rename a column

# %%
sales.rename(columns={"Profit":"Gain"},inplace=True)

# %%
sales
# Out:
#            State  Total_Expenses         Product  Sales   Market_Size   Gain  \
# 0     California            63.0        Amaretto  109.0  Major Market -131.0
# 1     California            55.0       Green Tea  201.0  Major Market   88.0
# 2     California           143.0     Caffe Mocha  289.0  Major Market   25.0
# 3     California           113.0  Decaf Espresso  576.0  Major Market  216.0
# 4     California            37.0       Chamomile  247.0  Major Market  148.0
# ...          ...             ...             ...    ...           ...    ...
# 4236   Wisconsin            34.0      Darjeeling   90.0  Small Market   20.0
# 4237   Wisconsin            36.0      Darjeeling  113.0  Small Market   31.0
# 4238   Wisconsin            86.0       Earl Grey  150.0  Small Market    1.0
# 4239   Wisconsin            79.0       Earl Grey  131.0  Small Market   -3.0
# 4240   Wisconsin            87.0       Earl Grey  165.0  Small Market    4.0
#
# ...

# %% [markdown]
# # modifying an actual value

# %%
sales.loc[2,"Total_Expenses"] = 500

# %%
sales
# Out:
#            State  Total_Expenses         Product  Sales   Market_Size   Gain  \
# 0     California            63.0        Amaretto  109.0  Major Market -131.0
# 1     California            55.0       Green Tea  201.0  Major Market   88.0
# 2     California           500.0     Caffe Mocha  289.0  Major Market   25.0
# 3     California           113.0  Decaf Espresso  576.0  Major Market  216.0
# 4     California            37.0       Chamomile  247.0  Major Market  148.0
# ...          ...             ...             ...    ...           ...    ...
# 4236   Wisconsin            34.0      Darjeeling   90.0  Small Market   20.0
# 4237   Wisconsin            36.0      Darjeeling  113.0  Small Market   31.0
# 4238   Wisconsin            86.0       Earl Grey  150.0  Small Market    1.0
# 4239   Wisconsin            79.0       Earl Grey  131.0  Small Market   -3.0
# 4240   Wisconsin            87.0       Earl Grey  165.0  Small Market    4.0
#
# ...

# %%
sales.at[2,'Total_Expenses'] = 700 #this is generally faster, so they say

# %%
sales
# Out:
#            State  Total_Expenses         Product  Sales   Market_Size   Gain  \
# 0     California            63.0        Amaretto  109.0  Major Market -131.0
# 1     California            55.0       Green Tea  201.0  Major Market   88.0
# 2     California           700.0     Caffe Mocha  289.0  Major Market   25.0
# 3     California           113.0  Decaf Espresso  576.0  Major Market  216.0
# 4     California            37.0       Chamomile  247.0  Major Market  148.0
# ...          ...             ...             ...    ...           ...    ...
# 4236   Wisconsin            34.0      Darjeeling   90.0  Small Market   20.0
# 4237   Wisconsin            36.0      Darjeeling  113.0  Small Market   31.0
# 4238   Wisconsin            86.0       Earl Grey  150.0  Small Market    1.0
# 4239   Wisconsin            79.0       Earl Grey  131.0  Small Market   -3.0
# 4240   Wisconsin            87.0       Earl Grey  165.0  Small Market    4.0
#
# ...

# %% [markdown]
# # adding or removing rows and columns

# %%
new_Column = sales['Total_Expenses'] + sales['Sales']

# %%
new_Column
# Out:
# 0       172.0
# 1       256.0
# 2       989.0
# 3       689.0
# 4       284.0
#         ...
# 4236    124.0
# 4237    149.0
# 4238    236.0
# 4239    210.0
# 4240    252.0
# Length: 4241, dtype: float64

# %%
sales['New_Column'] = new_Column

# %%
sales.head()
# Out:
#         State  Total_Expenses         Product  Sales   Market_Size   Gain  \
# 0  California            63.0        Amaretto  109.0  Major Market -131.0
# 1  California            55.0       Green Tea  201.0  Major Market   88.0
# 2  California           700.0     Caffe Mocha  289.0  Major Market   25.0
# 3  California           113.0  Decaf Espresso  576.0  Major Market  216.0
# 4  California            37.0       Chamomile  247.0  Major Market  148.0
#
#   Market  Marketing Product_Type  Inventory     Type  New_Column
# 0   West         40       Coffee     2947.0  Regular       172.0
# 1   West         24          Tea      659.0  Regular       256.0
# 2   West        109     Espresso      788.0  Regular       989.0
# 3   West         81     Espresso     1744.0    Decaf       689.0
# 4   West         26   Herbal Tea      809.0    Decaf       284.0

# %% [markdown]
# # remove a column

# %%
sales.drop(columns=['Product','Market_Size']) #remember that this is not parmanent, to make it so, use the "inplace='True'"
# Out:
#            State  Total_Expenses  Sales   Gain   Market  Marketing  \
# 0     California            63.0  109.0 -131.0     West         40
# 1     California            55.0  201.0   88.0     West         24
# 2     California           700.0  289.0   25.0     West        109
# 3     California           113.0  576.0  216.0     West         81
# 4     California            37.0  247.0  148.0     West         26
# ...          ...             ...    ...    ...      ...        ...
# 4236   Wisconsin            34.0   90.0   20.0  Central         11
# 4237   Wisconsin            36.0  113.0   31.0  Central         14
# 4238   Wisconsin            86.0  150.0    1.0  Central         57
# 4239   Wisconsin            79.0  131.0   -3.0  Central         49
# 4240   Wisconsin            87.0  165.0    4.0  Central         58
#
#      Product_Type  Inventory     Type  New_Column
# 0          Coffee     2947.0  Regular       172.0
# 1             Tea      659.0  Regular       256.0
# ...

# %% [markdown]
# # drop row(s)

# %%
sales.drop(index=0) #still not parmanent
# Out:
#            State  Total_Expenses         Product  Sales   Market_Size   Gain  \
# 1     California            55.0       Green Tea  201.0  Major Market   88.0
# 2     California           700.0     Caffe Mocha  289.0  Major Market   25.0
# 3     California           113.0  Decaf Espresso  576.0  Major Market  216.0
# 4     California            37.0       Chamomile  247.0  Major Market  148.0
# 5     California            99.0           Lemon  582.0  Major Market  291.0
# ...          ...             ...             ...    ...           ...    ...
# 4236   Wisconsin            34.0      Darjeeling   90.0  Small Market   20.0
# 4237   Wisconsin            36.0      Darjeeling  113.0  Small Market   31.0
# 4238   Wisconsin            86.0       Earl Grey  150.0  Small Market    1.0
# 4239   Wisconsin            79.0       Earl Grey  131.0  Small Market   -3.0
# 4240   Wisconsin            87.0       Earl Grey  165.0  Small Market    4.0
#
# ...

# %%
sales.head()
# Out:
#         State  Total_Expenses         Product  Sales   Market_Size   Gain  \
# 0  California            63.0        Amaretto  109.0  Major Market -131.0
# 1  California            55.0       Green Tea  201.0  Major Market   88.0
# 2  California           700.0     Caffe Mocha  289.0  Major Market   25.0
# 3  California           113.0  Decaf Espresso  576.0  Major Market  216.0
# 4  California            37.0       Chamomile  247.0  Major Market  148.0
#
#   Market  Marketing Product_Type  Inventory     Type  New_Column
# 0   West         40       Coffee     2947.0  Regular       172.0
# 1   West         24          Tea      659.0  Regular       256.0
# 2   West        109     Espresso      788.0  Regular       989.0
# 3   West         81     Espresso     1744.0    Decaf       689.0
# 4   West         26   Herbal Tea      809.0    Decaf       284.0
